-- %%
create or replace view gizmobox.bronze.refunds
as
select refund_id, payment_id, refund_timestamp, refund_amount, refund_reason
  from read_files("s3://s3-gizmobox/landing/operational-data/refunds",
      format=> 'csv',
      header=> True,
      delimiter=> ','
      );
